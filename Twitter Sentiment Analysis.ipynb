# %% [markdown]
# 3 Observations:
#
# 1. CBS tends to tweet out news that are more positive according to the sentiment scale
# 2. CNN tends to tweet out news that are more negative according to the sentiment scale
# 3. New York Times has an average overall compound score close to 0 while in the scatter plot,
# we see a pretty even distribution of tweets in both positive and negative range. This can indicate their tweets' sentiment are quite balanced.

# %%
# Dependencies
import tweepy
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('ggplot')

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
from config import (consumer_key, 
                    consumer_secret, 
                    access_token, 
                    access_token_secret)

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term
target_terms = ('@McDonalds','@BurgerKing','@innoutburger','@CarlsJr')
           
# Variable for max_id
oldest_tweet = None
    
# Variables for holding sentiments
sentiment = []

# Loop through all target users
for target in target_terms:
    
    # Counter
    counter = 1
    
    # Variable for holding the oldest tweet
    oldest_tweet = None

    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    negative_list = []
    neutral_list = []
    
    # Loop through 5 page of tweets (total 100 tweets)
    for x in range(5):

        # Get all tweets from home feed
        public_tweets = api.user_timeline(target, max_id = oldest_tweet)

        # Loop through all tweets 
        for tweet in public_tweets:

            # Print Tweets
#             print("Tweet %s: %s" % (counter, tweet["text"]))

            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            pos = results["pos"]
            neu = results["neu"]
            neg = results["neg"]
            tweets_ago = counter

            # Get Tweet ID, subtract 1, and assign to oldest_tweet
            oldest_tweet = tweet['id'] - 1

            # Add sentiments for each tweet into a list
            sentiment.append({"Date": tweet["created_at"],
                               "Source": target,
                               "Tweet": tweet["text"],
                               "Compound": compound,
                               "Positive": pos,
                               "Negative": neu,
                               "Neutral": neg,
                               "Tweets Ago": counter})

            # Add to counter 
            counter += 1

# %%
tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Tue Apr 03 14:24:34 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/messages/compo…',
#     'expanded_url': 'https://twitter.com/messages/compose?recipient_id=16103650',
#     'indices': [74, 97],
#     'url': 'https://t.co/v2r9kMWMCS'}],
#   'user_mentions': [{'id': 522473594,
#     'id_str': '522473594',
#     'indices': [0, 10],
#     'name': 'Mandatory.com',
#     'screen_name': 'Mandatory'}]},
#  'favorite_count': 1,
#  'favorited': False,
#  'geo': None,
#  'id': 981175629717569536,
#  'id_str': '981175629717569536',
#  'in_reply_to_screen_name': 'Mandatory',
#  'in_reply_to_status_id': 981079858292731906,
#  'in_reply_to_status_id_str': '981079858292731906',
#  'in_reply_to_user_id': 522473594,
#  'in_reply_to_user_id_str': '522473594',
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.falcon.io" rel="nofollow">Falcon Social Media Management </a>',
#  'text': '@Mandatory Love the thought! DM us for a free ticket to Ready Player One!\nhttps://t.co/v2r9kMWMCS',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Sep 02 21:46:59 +0000 2008',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Delishy-lishy loo is what we are to you so pick up and answer The Call y’all',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'carlsjr.com',
#       'expanded_url': 'http://www.carlsjr.com',
#       'indices': [0, 23],
#       'url': 'https://t.co/LIekBcxgvC'}]}},
#   'favourites_count': 4053,
#   'follow_request_sent': False,
#   'followers_count': 96632,
#   'following': False,
#   'friends_count': 3,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 16103650,
#   'id_str': '16103650',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 1250,
#   'location': '',
#   'name': "Carl's Jr.",
#   'notifications': False,
#   'profile_background_color': 'B2BCBE',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/689957197560807424/yaTUaxtV.jpg',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/689957197560807424/yaTUaxtV.jpg',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/16103650/1523389177',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/913527146273923072/LfHsIEAV_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/913527146273923072/LfHsIEAV_normal.jpg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'C0DFEC',
#   'profile_text_color': '333333',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'CarlsJr',
#   'statuses_count': 20163,
#   'time_zone': 'Pacific Time (US & Canada)',
#   'translator_type': 'none',
#   'url': 'https://t.co/LIekBcxgvC',
#   'utc_offset': -25200,
#   'verified': True}}

# %%
#Put the sentiment list into a dataframe
sentiment_pd = pd.DataFrame.from_dict(sentiment)

#export this data to csv
sentiment_pd.to_csv("sentiment_data.csv")

#Create a new dataframe for each news source
McDonalds = pd.DataFrame.from_dict(sentiment_pd.loc[sentiment_pd["Source"] == "@McDonalds"])
BurgerKing = pd.DataFrame.from_dict(sentiment_pd.loc[sentiment_pd["Source"] == "@BurgerKing"])
innoutburger = pd.DataFrame.from_dict(sentiment_pd.loc[sentiment_pd["Source"] == "@innoutburger"])
CarlsJr = pd.DataFrame.from_dict(sentiment_pd.loc[sentiment_pd["Source"] == "@CarlsJr"])

#Set up the scatter plots for each news source
McDonalds_x = plt.scatter(McDonalds["Tweets Ago"], McDonalds["Compound"], marker="o", facecolors="lightblue", edgecolors="black", alpha=1, label="McDonalds")
BurgerKing_x = plt.scatter(BurgerKing["Tweets Ago"], BurgerKing["Compound"], marker="o", facecolors="green", edgecolors="black", alpha=1, label="BurgerKing")
innoutburger_x = plt.scatter(innoutburger["Tweets Ago"], innoutburger["Compound"], marker="o", facecolors="red", edgecolors="black", alpha=1, label="In-N-Out")
CarlsJr_x = plt.scatter(CarlsJr["Tweets Ago"], CarlsJr["Compound"], marker="o", facecolors="blue", edgecolors="black", alpha=1, label="CarlsJr")

#Plot the scatterplot with the legends
lgd = plt.legend(handles=[McDonalds_x, BurgerKing_x, innoutburger_x, CarlsJr_x], loc='upper right', bbox_to_anchor=(1.4,1), fancybox=True, title="Fast Food Resturants")
lgd

#Get the current timestamp
now = datetime.now()
now = now.strftime("%Y-%m-%d %H:%M")

#set the title, x limit, x-label, and y-label
plt.title(f"Sentiment Analysis of Media Tweets ({now})")
plt.xlim([100,0]) 
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")

#Save the scatter plot as a png with extra parameters to have legend included in the image
plt.savefig('scatter_plot.png', bbox_extra_artists=(lgd,), bbox_inches='tight')

#Show the scatter plot
plt.show()

# %%
#Get an array of the mean compound for each news source
sentiment_mean = [McDonalds["Compound"].mean(), 
             BurgerKing["Compound"].mean(),
             innoutburger["Compound"].mean(),
             CarlsJr["Compound"].mean(),
             ]

#Set the range of the x_axis
x_axis = np.arange(len(sentiment_mean))

#Plot the bar chart and set unique colors for each news source
barlist = plt.bar(x_axis, sentiment_mean, align="edge")
barlist[0].set_color('lightblue')
barlist[1].set_color('green')
barlist[2].set_color('red')
barlist[3].set_color('blue')

barlist.patches

#set the tick locations and name the x_axis
tick_locations = [value+0.4 for value in x_axis]
plt.xticks(tick_locations, ["McDonalds", "BurgerKing", "innoutburger", "CarlsJr"])

#Give the bar chart a title, x-label and y-label
plt.ylabel("Tweet Polarity")
plt.xlabel("Media News Source")
plt.title(f"Overall Media Sentiment based on Twitter ({now})")

for rect in barlist:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 0.5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.1f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(0, space),          # Vertically shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        ha='center',                # Horizontally center label
        va=va)                      # Vertically align label differently for
                                    # positive and negative values.
#use seaborn library to set the style to white background
sns.set_style(style='white')

#save the figure
plt.savefig('bar_chart.png')

#Show the scatter plot
plt.show()

# %%
print(McDonalds)
# Out:
#     Compound                            Date  Negative  Neutral  Positive  \
# 0     0.0000  Tue Apr 17 16:04:24 +0000 2018     1.000    0.000     0.000
# 1    -0.3129  Tue Apr 17 16:02:10 +0000 2018     0.638    0.222     0.140
# 2     0.8309  Tue Apr 17 16:02:10 +0000 2018     0.562    0.000     0.438
# 3     0.0000  Tue Apr 17 16:02:01 +0000 2018     1.000    0.000     0.000
# 4     0.4926  Tue Apr 17 16:02:01 +0000 2018     0.775    0.000     0.225
# 5     0.3612  Tue Apr 17 16:01:29 +0000 2018     0.828    0.000     0.172
# 6     0.7579  Tue Apr 17 16:01:28 +0000 2018     0.444    0.000     0.556
# 7    -0.3129  Tue Apr 17 16:00:27 +0000 2018     0.660    0.208     0.132
# 8     0.3802  Tue Apr 17 16:00:00 +0000 2018     0.455    0.182     0.363
# 9     0.8502  Tue Apr 17 15:59:31 +0000 2018     0.618    0.000     0.382
# 10   -0.3129  Tue Apr 17 15:58:32 +0000 2018     0.638    0.222     0.140
# 11    0.8502  Tue Apr 17 15:58:32 +0000 2018     0.618    0.000     0.382
# 12    0.0000  Tue Apr 17 15:58:32 +0000 2018     1.000    0.000     0.000
# 13    0.6588  Tue Apr 17 15:58:32 +0000 2018     0.672    0.000     0.328
# 14    0.7777  Tue Apr 17 15:58:00 +0000 2018     0.391    0.000     0.609
# 15    0.8658  Tue Apr 17 15:58:00 +0000 2018     0.318    0.000     0.682
# 16    0.5386  Tue Apr 17 15:57:32 +0000 2018     0.509    0.147     0.344
# 17    0.8502  Tue Apr 17 15:57:32 +0000 2018     0.602    0.000     0.398
# 18    0.8502  Tue Apr 17 15:57:01 +0000 2018     0.602    0.000     0.398
# 19    0.7712  Tue Apr 17 15:54:43 +0000 2018     0.677    0.000     0.323
# 20    0.9358  Tue Apr 17 15:54:27 +0000 2018     0.282    0.000     0.718
# 21    0.0000  Tue Apr 17 15:52:02 +0000 2018     1.000    0.000     0.000
# 22    0.6996  Tue Apr 17 15:50:25 +0000 2018     0.429    0.114     0.457
# 23   -0.3129  Tue Apr 17 15:50:00 +0000 2018     0.660    0.208     0.132
# 24    0.8122  Tue Apr 17 15:49:29 +0000 2018     0.549    0.000     0.451
# 25    0.7579  Tue Apr 17 15:48:53 +0000 2018     0.444    0.000     0.556
# 26    0.0000  Tue Apr 17 15:48:53 +0000 2018     1.000    0.000     0.000
# 27    0.7777  Tue Apr 17 15:48:53 +0000 2018     0.435    0.000     0.565
# 28    0.9370  Tue Apr 17 15:48:00 +0000 2018     0.417    0.000     0.583
# 29   -0.3129  Tue Apr 17 15:47:30 +0000 2018     0.660    0.208     0.132
# ..       ...                             ...       ...      ...       ...
# 70    0.8221  Tue Apr 17 14:35:00 +0000 2018     0.397    0.000     0.603
# 71    0.8502  Tue Apr 17 14:26:00 +0000 2018     0.618    0.000     0.382
# 72    0.8313  Tue Apr 17 14:25:30 +0000 2018     0.660    0.000     0.340
# 73   -0.3129  Tue Apr 17 14:25:30 +0000 2018     0.613    0.237     0.150
# 74    0.8718  Tue Apr 17 14:25:30 +0000 2018     0.378    0.000     0.622
# 75    0.5093  Tue Apr 17 14:23:00 +0000 2018     0.785    0.000     0.215
# 76    0.0000  Tue Apr 17 14:21:00 +0000 2018     1.000    0.000     0.000
# 77    0.7494  Tue Apr 17 14:20:32 +0000 2018     0.556    0.000     0.444
# 78    0.5080  Tue Apr 17 14:20:32 +0000 2018     0.646    0.000     0.354
# 79    0.8502  Tue Apr 17 14:20:32 +0000 2018     0.618    0.000     0.382
# 80    0.8502  Tue Apr 17 14:20:03 +0000 2018     0.618    0.000     0.382
# 81    0.4404  Tue Apr 17 14:20:00 +0000 2018     0.769    0.067     0.164
# 82    0.9299  Tue Apr 17 14:18:52 +0000 2018     0.225    0.000     0.775
# 83    0.0000  Tue Apr 17 14:17:00 +0000 2018     1.000    0.000     0.000
# 84    0.8122  Tue Apr 17 14:15:23 +0000 2018     0.403    0.000     0.597
# 85    0.8502  Tue Apr 17 14:14:54 +0000 2018     0.618    0.000     0.382
# 86    0.4926  Tue Apr 17 14:14:24 +0000 2018     0.849    0.000     0.151
# 87   -0.3129  Tue Apr 17 14:13:30 +0000 2018     0.613    0.237     0.150
# 88    0.8070  Tue Apr 17 14:13:00 +0000 2018     0.523    0.000     0.477
# 89    0.0000  Tue Apr 17 14:11:52 +0000 2018     1.000    0.000     0.000
# 90    0.7579  Tue Apr 17 14:11:30 +0000 2018     0.444    0.000     0.556
# 91    0.5848  Tue Apr 17 14:10:00 +0000 2018     0.556    0.000     0.444
# 92    0.3612  Tue Apr 17 14:09:28 +0000 2018     0.828    0.000     0.172
# 93    0.8832  Tue Apr 17 14:08:29 +0000 2018     0.538    0.000     0.462
# 94    0.0000  Tue Apr 17 14:06:00 +0000 2018     1.000    0.000     0.000
# 95    0.3612  Tue Apr 17 14:04:56 +0000 2018     0.828    0.000     0.172
# 96    0.8221  Tue Apr 17 14:04:26 +0000 2018     0.345    0.000     0.655
# 97    0.3612  Tue Apr 17 14:04:26 +0000 2018     0.828    0.000     0.172
# 98    0.0000  Tue Apr 17 14:04:00 +0000 2018     1.000    0.000     0.000
# 99    0.6696  Tue Apr 17 14:01:00 +0000 2018     0.572    0.000     0.428
#
#         Source                                              Tweet  Tweets Ago
# 0   @McDonalds  @BESorenson It’s all about options, Benjamin! ...           1
# 1   @McDonalds  @alyssa_bullard_ Alert! We have a McD’s emerge...           2
# 2   @McDonalds  @LulTrippyShawd Glad you feel that way! Maybe ...           3
# 3   @McDonalds  @MaysenWillard The UberEATS website &amp; app ...           4
# 4   @McDonalds  @Rahsaan_J Aw, thanks Rahsaan, you must be the...           5
# 5   @McDonalds  @Katelyn_Loren_ It’s like that old saying “The...           6
# 6   @McDonalds  @ryleesmakeup Sounds like you’re livin’ the dr...           7
# 7   @McDonalds  @belcalis_ Alert! We have a McD’s emergency! S...           8
# 8   @McDonalds  @DrRandyESimmons Thanks for stopping by, Randy! 😊           9
# 9   @McDonalds  @KhrisKil Sounds good to us, Chris! We are alw...          10
# 10  @McDonalds  @taylorrenee73 Alert! We have a McD’s emergenc...          11
# 11  @McDonalds  @LaurenBarnello Sounds good to us, Lauren! We ...          12
# 12  @McDonalds  @ginnygf We’re looking forward to seeing you s...          13
# 13  @McDonalds  @BayntonJaylee That's great, Jaylee! We look f...          14
# 14  @McDonalds  @kaymids972 Sounds like you’re livin’ the drea...          15
# 15  @McDonalds  @Whose_NELSON Sounds like you’re livin’ the dr...          16
# 16  @McDonalds  @callmeemmaa Alert! We have a McD’s emergency!...          17
# 17  @McDonalds  @badd_erikaa Sounds good to us! We are always ...          18
# 18  @McDonalds  @Norah2theJean Sounds good to us! We are alway...          19
# 19  @McDonalds  @Thedog1Justin We can't wait for you to try it...          20
# 20  @McDonalds  @faith_gilliam That’s cool, Faith! Sounds like...          21
# 21  @McDonalds                    @JCruz2_ Air high-five, Jordan!          22
# 22  @McDonalds  @SpaceePeeebles Thanks for stopping by, Peter....          23
# 23  @McDonalds  @tayyydykinss Alert! We have a McD’s emergency...          24
# 24  @McDonalds  @Snowprincess719 That's great, Shannon! We can...          25
# 25  @McDonalds  @behlieve Sounds like you’re livin’ the dream,...          26
# 26  @McDonalds                   @chase_lax Air high-five, Chase!          27
# 27  @McDonalds  @SelectiveSavage Sounds like you’re livin’ the...          28
# 28  @McDonalds  @_LizHoward Thanks for sharing, Elizabeth! We ...          29
# 29  @McDonalds  @Bmccallick Alert! We have a McD’s emergency! ...          30
# ..         ...                                                ...         ...
# 70  @McDonalds  @hoyoskarlaa Aw, you’re a real SWEETheart, Kar...          71
# 71  @McDonalds  @loveee_livvv Sounds good to us, Olivia! We ar...          72
# 72  @McDonalds  @jeanmadisonn Hi, Madison! Thanks for reaching...          73
# 73  @McDonalds  @fxckduude Alert! We have a McD’s emergency! S...          74
# 74  @McDonalds  @_OnePunchGirl_ Sounds like you have great tas...          75
# 75  @McDonalds  @aliyafoxx Aw, Ali! Your mum must be the sweet...          76
# 76  @McDonalds  @KaylaKaylar01 The UberEATS website &amp; app ...          77
# 77  @McDonalds  @ZuluWarrior1222 Nice! Don't let them out of y...          78
# 78  @McDonalds  @Forsibley Treat yourself, Stephanie! You've e...          79
# 79  @McDonalds  @kristensolis443 Sounds good to us, Kristen! W...          80
# 80  @McDonalds  @LMelody08 Sounds good to us, Lucero! We are a...          81
# 81  @McDonalds  @_That1MixedGirl We’re sorry to hear about you...          82
# 82  @McDonalds  @hulkhogan15 Sounds like a great way to celebr...          83
# 83  @McDonalds  @mbarranco_ The UberEATS website &amp; app wil...          84
# 84  @McDonalds             @yekerit Hey Eli, thanks for the love!          85
# 85  @McDonalds  @sherlock2g Sounds good to us, Robin! We are a...          86
# 86  @McDonalds  @wylie_noel We're diggin’ your enthusiasm for ...          87
# 87  @McDonalds  @brittanybng4 Alert! We have a McD’s emergency...          88
# 88  @McDonalds  @_iAttempt2Care That's great to hear, Angel! T...          89
# 89  @McDonalds               @xDickey You are making us hungry...          90
# 90  @McDonalds  @oofrichie Sounds like you’re livin’ the dream...          91
# 91  @McDonalds  @killercunt Sounds like you’re livin’ the drea...          92
# 92  @McDonalds  @morganbee_ It’s like that old saying “The sto...          93
# 93  @McDonalds  @smithdante59 Awesome! You must be hearing tho...          94
# 94  @McDonalds        @Donielle_ We'll have some waiting for you!          95
# 95  @McDonalds  @QL_Artist It’s like that old saying “The stom...          96
# 96  @McDonalds   @ThatStudAlvaro Aw, you’re a real SWEETheart! :)          97
# 97  @McDonalds  @LishaaaG It’s like that old saying “The stoma...          98
# 98  @McDonalds  @MikoMarbella Aw, shucks; you're making us blush!          99
# 99  @McDonalds     @katierocksit Aw, you're the best ever, Katie!         100
#
# [100 rows x 8 columns]
